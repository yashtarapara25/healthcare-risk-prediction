# %%
#import library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load dataaset

# %%
data=pd.read_csv('Healthcare_Risk_Data.csv')

# %%
data.head()
# Out:
#    PatientID  Age  Gender  Glucose  BloodPressure   BMI  Insulin  \
# 0          1   69    Male      109             57  31.4      136
# 1          2   32    Male      120             66  27.0       84
# 2          3   89  Female      141             61  27.8       77
# 3          4   78    Male       65             73  29.0       91
# 4          5   38  Female      184             64  31.1       54
#
#    DiabetesPedigree Smoking    Exercise FamilyHistory  Outcome
# 0              0.55      No         NaN            No        0
# 1              0.37     Yes     Regular            No        0
# 2              0.32      No         NaN            No        0
# 3              0.37     Yes  Occasional           Yes        0
# 4              0.38      No  Occasional            No        0

# %%
#for first 10 values
data.head(10)
# Out:
#    PatientID  Age  Gender  Glucose  BloodPressure   BMI  Insulin  \
# 0          1   69    Male      109             57  31.4      136
# 1          2   32    Male      120             66  27.0       84
# 2          3   89  Female      141             61  27.8       77
# 3          4   78    Male       65             73  29.0       91
# 4          5   38  Female      184             64  31.1       54
# 5          6   41    Male      127             76  36.2       76
# 6          7   20    Male       73             94  24.3      109
# 7          8   39    Male      124             76  30.4      117
# 8          9   70  Female       92             84  25.1      143
# 9         10   19    Male       90             58  27.1       50
#
#    DiabetesPedigree Smoking    Exercise FamilyHistory  Outcome
# 0              0.55      No         NaN            No        0
# 1              0.37     Yes     Regular            No        0
# ...

# %%
#last five records
data.tail()
# Out:
#       PatientID  Age  Gender  Glucose  BloodPressure   BMI  Insulin  \
# 9995       9996   88  Female      137             49  29.0       98
# 9996       9997   43    Male      154             72  24.9       53
# 9997       9998   63    Male      162             58  36.1       19
# 9998       9999   63  Female      126             54  24.0       17
# 9999      10000   31    Male      140             68  27.5       71
#
#       DiabetesPedigree Smoking    Exercise FamilyHistory  Outcome
# 9995              0.60     Yes  Occasional            No        1
# 9996              0.51     Yes     Regular            No        1
# 9997              0.31      No         NaN            No        0
# 9998              0.66     Yes         NaN            No        1
# 9999              0.81      No     Regular           Yes        0

# %%
#Basic Information

# %%
#Overview OF Data
data.info()

#shape
print(f"Shape :{data.shape}")  #10000 rows and 12 coulmns
print("missing Values : \n",data.isnull().sum())   #only Exrices coullmns have 3364 NULL values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PatientID         10000 non-null  int64
#  1   Age               10000 non-null  int64
#  2   Gender            10000 non-null  object
#  3   Glucose           10000 non-null  int64
#  4   BloodPressure     10000 non-null  int64
#  5   BMI               10000 non-null  float64
#  6   Insulin           10000 non-null  int64
#  7   DiabetesPedigree  10000 non-null  float64
#  8   Smoking           10000 non-null  object
#  9   Exercise          6636 non-null   object
#  10  FamilyHistory     10000 non-null  object
#  11  Outcome           10000 non-null  int64
# dtypes: float64(2), int64(6), object(4)
# memory usage: 937.6+ KB
# Shape :(10000, 12)
# missing Values :
#  PatientID              0
# Age                    0
# Gender                 0
# Glucose                0
# ...

# %%
#describe
data.describe().T #using T rows convert in coullmns and coullmns place on rows
# Out:
#                     count         mean          std    min      25%     50%  \
# PatientID         10000.0  5000.500000  2886.895680   1.00  2500.75  5000.5
# Age               10000.0    53.539700    20.757324  18.00    36.00    53.0
# Glucose           10000.0   119.410900    29.404386  15.00    99.00   119.0
# BloodPressure     10000.0    69.495600    10.153398  32.00    63.00    69.5
# BMI               10000.0    28.026290     5.003832   9.80    24.70    28.0
# Insulin           10000.0    79.347400    39.546071 -66.00    53.00    80.0
# DiabetesPedigree  10000.0     0.496897     0.200509  -0.22     0.36     0.5
# Outcome           10000.0     0.347400     0.476168   0.00     0.00     0.0
#
#                       75%       max
# PatientID         7500.25  10000.00
# Age                 72.00     89.00
# Glucose            139.00    219.00
# BloodPressure       76.00    109.00
# BMI                 31.40     45.90
# Insulin            106.00    222.00
# ...

# %%
#data cleaning nan replace with 0

data.fillna(0, inplace=True)

# %%
data.head()
# Out:
#    PatientID  Age  Gender  Glucose  BloodPressure   BMI  Insulin  \
# 0          1   69    Male      109             57  31.4      136
# 1          2   32    Male      120             66  27.0       84
# 2          3   89  Female      141             61  27.8       77
# 3          4   78    Male       65             73  29.0       91
# 4          5   38  Female      184             64  31.1       54
#
#    DiabetesPedigree Smoking    Exercise FamilyHistory  Outcome
# 0              0.55      No           0            No        0
# 1              0.37     Yes     Regular            No        0
# 2              0.32      No           0            No        0
# 3              0.37     Yes  Occasional           Yes        0
# 4              0.38      No  Occasional            No        0

# %%
data.isna().sum()
# Out:
# PatientID           0
# Age                 0
# Gender              0
# Glucose             0
# BloodPressure       0
# BMI                 0
# Insulin             0
# DiabetesPedigree    0
# Smoking             0
# Exercise            0
# FamilyHistory       0
# Outcome             0
# dtype: int64

# %%
#find mean of  Age , glucose , bloodpressure , bmi
data[['Age','Glucose','BloodPressure','BMI']].mean()
# Out:
# Age               53.53970
# Glucose          119.41090
# BloodPressure     69.49560
# BMI               28.02629
# dtype: float64

# %%
#find min of  Age , glucose , bloodpressure , bmi
data[['Age','Glucose','BloodPressure','BMI']].min()
# Out:
# Age              18.0
# Glucose          15.0
# BloodPressure    32.0
# BMI               9.8
# dtype: float64

# %%
#find max of  Age , glucose , bloodpressure , bmi
data[['Age','Glucose','BloodPressure','BMI']].max()
# Out:
# Age               89.0
# Glucose          219.0
# BloodPressure    109.0
# BMI               45.9
# dtype: float64

# %%
#find std of  Age , glucose , bloodpressure , bmi
data[['Age','Glucose','BloodPressure','BMI']].std()
# Out:
# Age              20.757324
# Glucose          29.404386
# BloodPressure    10.153398
# BMI               5.003832
# dtype: float64

# %%
#value conts of Gender
data['Gender'].value_counts()
# Out:
# Gender
# Female    5072
# Male      4928
# Name: count, dtype: int64

# %%
#value conts of exrcise
data['Exercise'].value_counts()
# Out:
# Exercise
# Regular       3356
# Occasional    3280
# Name: count, dtype: int64

# %%
#value conts of Outcome
data['Outcome'].value_counts()
# Out:
# Outcome
# 0    6526
# 1    3474
# Name: count, dtype: int64

# %%
#Visulation

# %%
# Histogram of numeric features
data.hist(figsize=(15, 10), bins=30)
plt.tight_layout()
plt.show()

# %%
#value counts of which type of age is most health problem
data['Age'].value_counts()

#top five helth issues and bottem five low helth issues age
# Out:
# Age
# 34    175
# 43    163
# 71    159
# 36    159
# 38    157
#      ...
# 31    122
# 67    120
# 24    117
# 51    116
# 22    113
# Name: count, Length: 72, dtype: int64

# %%
#bar plot of Which type of Age Is more health isuese
plt.figure(figsize=(15,10))  

age_counts = data['Age'].value_counts().sort_index()

plt.bar(age_counts.index, age_counts.values,color='purple')
plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.title("Age Distribution of Patients")
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
#find how many people smoking
data['Smoking'].value_counts()
# Out:
# Smoking
# No     5023
# Yes    4977
# Name: count, dtype: int64

# %%
#pie plot of smoking ratio

# Count the number of Yes and No in the Smoking column
smoking_counts = data['Smoking'].value_counts()

labels = smoking_counts.index  #index show name
sizes = smoking_counts.values  #values show value of amount

plt.figure(figsize=(7,7))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', colors=['green','red'])
plt.title('Smoking Ratio in Patients')
plt.show()

# %%
#Categorical Feature Distributions
#Seaborn

# %%
#show comperison between diabetic and non_diabetic
sns.countplot(x='Outcome', data=data)
plt.title("Diabetic vs Non-Diabetic")
# Out:
# Text(0.5, 1.0, 'Diabetic vs Non-Diabetic')

# %%
#diabets risk compersion with male and female
sns.countplot(x='Gender', hue='Outcome', data=data)
plt.title("Gender vs Diabetes Risk")
# Out:
# Text(0.5, 1.0, 'Gender vs Diabetes Risk')

# %%
#exercies compersion with male and female
sns.countplot(x='Gender', hue='Exercise', data=data)
plt.title("Gender vs Exericise")
# Out:
# Text(0.5, 1.0, 'Gender vs Exericise')

# %%
#Boxplots to Spot Outliers

# %%
#Show Glucose Leval By Outcome
sns.boxplot(x='Outcome', y='Glucose', data=data)
plt.title("Glucose levels by Outcome")
# Out:
# Text(0.5, 1.0, 'Glucose levels by Outcome')

# %%
#Show BMI Leval By Outcome
sns.boxplot(x='Outcome', y='BMI', data=data)
plt.title("BMI by Outcome")
# Out:
# Text(0.5, 1.0, 'BMI by Outcome')

# %%
#Correlation Heatmap

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
#Group Insights

# %%
#find mean of glucose , bmi , age wih outcome 
data.groupby('Outcome')[['Glucose', 'BMI', 'Age']].mean()
# Out:
#             Glucose        BMI        Age
# Outcome
# 0        119.514097  28.011600  53.471805
# 1        119.217041  28.053886  53.667242

# %%
#find min of glucose , bmi , age wih outcome 
data.groupby('Outcome')[['Glucose', 'BMI', 'Age']].min()
# Out:
#          Glucose   BMI  Age
# Outcome
# 0             24   9.8   18
# 1             15  10.5   18

# %%
#find max of glucose , bmi , age wih outcome 
data.groupby('Outcome')[['Glucose', 'BMI', 'Age']].max()
# Out:
#          Glucose   BMI  Age
# Outcome
# 0            215  45.9   89
# 1            219  45.3   89

# %%
#find std of glucose , bmi , age wih outcome 
data.groupby('Outcome')[['Glucose', 'BMI', 'Age']].std()
# Out:
#            Glucose       BMI        Age
# Outcome
# 0        29.314932  5.025425  20.747452
# 1        29.574954  4.963619  20.778245

# %%
X = data.drop(columns=['PatientID', 'Outcome'])
y = data['Outcome']

# %%
#Convert columns like Gender, Smoking, Exercise, FamilyHistory into numbers:
X_encoded = pd.get_dummies(X, drop_first=True)

# %%
#Split Dataset
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
#Train Machine Learning Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score

model = RandomForestClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
#Evaluate the Model
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.6385
#               precision    recall  f1-score   support
#
#            0       0.65      0.96      0.78      1300
#            1       0.36      0.04      0.08       700
#
#     accuracy                           0.64      2000
#    macro avg       0.51      0.50      0.43      2000
# weighted avg       0.55      0.64      0.53      2000

# %%
from sklearn.metrics import confusion_matrix

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, fmt='d', cmap='Blues')
plt.title("Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
import os

# Create the folder if it doesn't exist
os.makedirs('models', exist_ok=True)

# Now save the model
import joblib
joblib.dump(model, 'models/disease_predictor.pkl')
# Out:
# ['models/disease_predictor.pkl']
